# %% [markdown]
# <img src="http://www.tut.fi/cs/groups/public/@l102/@news/@p/documents/tekn/tty-logo-TTYINTERNETEN-png.png" align="right" />

# %%
# It would be a good idea to automate data upload
furl = 'http://data.insideairbnb.com/canada/qc/montreal/2016-05-04/data/listings.csv.gz'
fname = 'listings.csv.gz'

# %%
import glob
print(glob.glob("*"))
# Out:
# ['work', 'Untitled.ipynb', 'listings (2).csv']

# %%
import pandas as pd

# %%
df = pd.read_csv('listings (2).csv')

# %%
df.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   543823   https://www.airbnb.com/rooms/543823  20160504002227   2016-05-04
# 1   533084   https://www.airbnb.com/rooms/533084  20160504002227   2016-05-04
# 2   488959   https://www.airbnb.com/rooms/488959  20160504002227   2016-05-04
# 3  5915025  https://www.airbnb.com/rooms/5915025  20160504002227   2016-05-04
# 4   753348   https://www.airbnb.com/rooms/753348  20160504002227   2016-05-04
#
#                                  name  \
# 0     Nice large bedroom in Outremont
# 1    parisian apartment in Outremont
# 2    Nice flat in great neighbourhood
# 3  Big Gorgeous Sunny Gem w Roof Deck
# 4          Cozy apartment in Montreal
#
#                                              summary  \
# 0                                                NaN
# 1  looking for people interested in a middle-term...
# 2                                                NaN
# ...

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
# ...
